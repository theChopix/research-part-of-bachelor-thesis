# %%
import sys
sys.path.append('../../utils')
import data_funcs as utils

# %%
X,y,features = utils.get_validation_data('../../data/validation-set.tsv')

# %%
import pybaobabdt
import pandas as pd
from scipy.io import arff
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(max_depth=4);
clf.fit(X,y);

# %%
features = []
for i in range(X.shape[1]):
    features.append("feature_" + str(i))
features = features.apply(lambda x: x.encode('latin-1'))

# %%
y = y.astype(str)
y = y.apply(lambda x: x.encode('latin-1'))

# %%
ax = pybaobabdt.drawTree(clf, size=10, dpi=72, features=features)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_163799/2059213110.py in <module>
# ----> 1 ax = pybaobabdt.drawTree(clf, size=10, dpi=72, features=features)
#
# ~/anaconda3/lib/python3.9/site-packages/pybaobabdt/__init__.py in drawTree(decisionTreeClassifier, features, model, colormap, size, dpi, ratio, classes, maxdepth, ax)
#     501         fontSize = linewidth_from_data_units(min(55,nodeEdgesWidthT[0][c]), ax, reference='y')
#     502         lineSize = linewidth_from_data_units(5,  ax, reference='y')
# --> 503         text = plt.annotate(str(class_names[c], 'utf-8'), xy=(x,y), color='black', size=fontSize, ha='left', va='bottom', rotation=45)
#     504         #text = plt.annotate(str(class_names[c]), xy=(x,y), color='black', size=fontSize, ha='left', va='bottom', rotation=45)
# ...

# %%
type(y[0])
# Out:
# numpy.bytes_

# %%
y = y.astype(str)
y = y.apply(lambda x: x.encode('utf-8'))

# %%
y
# Out:
# 0       b"b'1'"
# 1       b"b'1'"
# 2       b"b'1'"
# 3       b"b'1'"
# 4       b"b'1'"
#          ...
# 2956    b"b'0'"
# 2957    b"b'0'"
# 2958    b"b'0'"
# 2959    b"b'0'"
# 2960    b"b'0'"
# Name: box, Length: 2961, dtype: object

# %%
y
# Out:
# 0       b'1.0'
# 1       b'1.0'
# 2       b'1.0'
# 3       b'1.0'
# 4       b'1.0'
#          ...
# 2956    b'0.0'
# 2957    b'0.0'
# 2958    b'0.0'
# 2959    b'0.0'
# 2960    b'0.0'
# Name: box, Length: 2961, dtype: object
